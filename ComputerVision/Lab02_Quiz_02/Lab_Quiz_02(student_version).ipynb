# %% [markdown]
# 1.  **Computer Vision and Pattern Recognition**
# 2.  **CS-342**
# 3.  **Lab_Quiz_02**
# 4.  **Date : 27-01-2020**
# 5.  **Full Marks : 100**
# 6.  **Duration : 40 Minutes.**
#
# ## Save the file as FIRSTNAME_Lab_Quiz_02.ipynb and submit it on Google Classroom. Example: Seshadri_Lab_Quiz_02.ipynb

# %% [markdown]
# ![alt text](https://media.giphy.com/media/1ymLtXP7NLzaf38mRf/giphy.gif)

# %% [markdown]
# **Please fill the following details :**
#
# 1.   **NAME :**
# 2.   **ID :**
# 3.   **STREAM :**

# %% [markdown]
# **IMPORT HEADERS**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# **Question 1 : Read Image Pop_01.jpg and convolve it with a Gaussian Kernel of following specifications :**
# 1.  **Size :** 15 x 15
# 2.  **Standard Deviation :** 20

# %% [markdown]
# **HINT :** You can use the Functions cv2.getGaussianKernel() and cv2.filter2D().

# %% [markdown]
# **MARKS : 20**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **Your Code in the Below Cell:**

# %% [markdown]
# **Question 2 : Read Image Pop_01.jpg and convolve it with a Kernel of Size : 15 x 15 , Standard Deviation : 20 and plot the Results. you should perdfom the actions using Seperable Filters.**

# %% [markdown]
# **HINT :** You can use the function cv2.sepFilter2D()

# %% [markdown]
# **MARKS : 30**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **Your Code in the Below Cell :**

# %% [markdown]
# **Question 3 : Use cv2.GaussianBlur() with kernel size(15 X 15), SIGMA_X = 20, SIGMA_Y = 20 to blur the Image and produce the output.**

# %% [markdown]
# **HINT :** The function to be used is already specified in the question.

# %% [markdown]
# **MARKS : 20**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %%
# Out:
# Text(0.5, 1.0, 'After Convolution')

# %% [markdown]
# **Your Code in the Below Cell :**

# %% [markdown]
# **Question 4 :**
#
# Load Image 1 = TJ1.jpg and Image 2 = TJ2.jpg
#
# 1.   Image 1 should be given 80% weightage and Image 2 should be given 20% weightage.
# 2.   Image 1 should be given 20% weightage and Image 2 should be given 80% weightage.

# %% [markdown]
# **HINT :** You can use the Functions cv2.cvtColor() and cv2.addWeighted().

# %% [markdown]
# **MARKS : 30**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %%
# Out:
# The shape of Image 1 is :  (360, 480, 3)
# The shape of Image 2 is :  (451, 602, 3)
# The new shape of Image 2 is :  (360, 480, 3)

# %% [markdown]
# **Your Code in the Below Cell :**

# %% [markdown]
# ![Thank-You](https://cdn.pizap.com/pizapfiles/images/thank_you_card_maker_app01.jpg)
