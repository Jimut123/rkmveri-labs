# %% [markdown]
# **IMPORT HEADERS**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# **READ IMAGE**

# %%
img = cv2.imread("/content/Portada.jpg",0)

# %% [markdown]
# **DEFINING DIFFERENT KERNELS**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %%
# Out:
# The Sobel_X Kernel is :
#
# [[-1  0  1]
#  [-2  0  2]
#  [-1  0  1]]
#
# The Sobel_Y Kernel is :
#
# [[-1 -2 -1]
#  [ 0  0  0]
#  [ 1  2  1]]
#
# The Laplacian Kernel is :
#
# [[0 1 0]
#  [1 4 1]
#  [0 1 0]]

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %% [markdown]
# **CONVOLVING USING SOBEL_X KERNEL**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %% [markdown]
# **CONVOLVING USING SOBEL_Y KERNEL**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %% [markdown]
# **CONVOLVING USING LAPLACIAN KERNEL**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %% [markdown]
# **FINDING OUT IMAGE GRADIENTS**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **CANNY EDGE DETECTION**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**
