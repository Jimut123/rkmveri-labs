# %% [markdown]
# **IMPORT HEADERS**

# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt

# %% [markdown]
# **UNIT I : Frequency Response**

# %% [markdown]
# **1. Fourier Transform in Numpy**
#
#
# > **PART 1 : Fourier Transform**
#
# > **PART 2 : Inverse Fourier Transform**

# %% [markdown]
# **PART 1 : Fourier Transform**

# %% [markdown]
# **STEP I : Read and Display Image in Color and Gray-Scale.**
# > **Supporting Lines of Code :**
# > 1.   **Convert To Gray-Scale :** cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# >

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.figure(figsize=(12,12))

plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.axis("off")
plt.title("Color Image")

plt.subplot(1,2,2)
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("Gray-Scale Image")

plt.show()

# %% [markdown]
# **STEP II : Perform Fourier Transform and Display the Magnitude Spectrum in Gray-Scale.**
#
# > **Supporting Lines of Code :**
# > 1.   **For Finding Fourier Transform :** np.fft.fft2(img_gray)
# > 2.   **For Finding Magnitude Spectrum :** 20*np.log(np.abs(f))

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.imshow(magnitude_spectrum,cmap="gray")
plt.axis("off")
plt.title("Magnitude Spectrum with Low Frequency at the Corners")
plt.show()

# %% [markdown]
# **STEP III : Shift the Low Frequency Component to the Middle.**
# > **Supporting Lines of Code :**
# > 1.   **For Shifting the Low Frequency Component :** np.fft.fftshift(f)

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.imshow(magnitude_spectrum,cmap="gray")
plt.axis("off")
plt.title("Magnitude Spectrum with Low Frequency at the Center")
plt.show()

# %% [markdown]
# **PART 2 : Inverse Fourier Transform**

# %% [markdown]
# **STEP I : Take a Rectangular Window of Size 60 X 60 in the center and fill it up with Zero and Then display the Magnitude Spectrum.**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.imshow(magnitude_spectrum,cmap="gray")
plt.axis("off")
plt.title("Magnitude Spectrum with 60 x 60 0s in the Center")
plt.show()

# %% [markdown]
# **STEP II : Do the Inverse of Shifting and Display the Magnitude Spectrum.**
#
# > **Supporting Lines of Code :**
# > 1. **Inverse Fourier Transform Shift :** np.fft.ifftshift(fshift)

# %% [markdown]
# **EXPECTED OUTPUT :**

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.imshow(magnitude_spectrum,cmap="gray")
plt.show()

# %% [markdown]
# **STEP III : Finally Performing Inverse Fourier Transform.**
#
# > **Supporting Lines of Code :**
# > 1. **Inverse Fourier Transform :** np.fft.ifft2(f_ishift)
# > 2. **Convert Complex Number to Real Number :** np.real(img_back)

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.imshow(img_back,cmap="gray")
plt.show()

# %% [markdown]
# **2. Fourier Transform in OPENCV**
#
#
# > **PART 1 : Fourier Transform**
#
# > **PART 2 : Inverse Fourier Transform**

# %% [markdown]
# **PART 1 : Fourier Transform**

# %% [markdown]
# **STEP I : Read and Display Image in Color and Gray-Scale.**
# > **Supporting Lines of Code :**
# > 1.   **Convert To Gray-Scale :** cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# >

# %%
img = cv2.imread('/content/dora.jpg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(12,12))

plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.axis("off")
plt.title("Color Image")

plt.subplot(1,2,2)
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("Gray-Scale Image")

plt.show()

# %% [markdown]
# **STEP II : Perform Fourier Transform and Display the Magnitude Spectrum in Gray-Scale.**
#
# > **Supporting Lines of Code :**
# > 1.   **For Finding Fourier Transform :** cv2.dft(np.float32(img_gray),flags = cv2.DFT_COMPLEX_OUTPUT)
# > 2.   **For Finding Magnitude Spectrum :** 20*np.log(cv2.magnitude(dft[:,:,0],dft[:,:,1]))

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# ****

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.imshow(magnitude_spectrum,cmap="gray")
plt.axis("off")
plt.title("Magnitude Spectrum with Low Frequency at the Corners")
plt.show()

# %% [markdown]
# **STEP III : Shift the Low Frequency Component to the Middle.**
# > **Supporting Lines of Code :**
# > 1.   **For Shifting the Low Frequency Component :** np.fft.fftshift(f)

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.imshow(magnitude_spectrum,cmap="gray")
plt.axis("off")
plt.title("Magnitude Spectrum with Low Frequency at the Center")
plt.show()

# %% [markdown]
# **PART 2 : Inverse Fourier Transform**

# %% [markdown]
# **STEP I : Take a Rectangular Window of Size 60 X 60 in the center and fill it up with One.**

# %%
rows, cols = img_gray.shape
crow,ccol = rows//2 , cols//2
mask = np.zeros((rows,cols,2),np.uint8)
mask[crow-30:crow+30, ccol-30:ccol+30] = 1

# %% [markdown]
# **STEP II : Apply the Mask.**

# %%
fshift = dft_shift*mask

# %% [markdown]
# **STEP III :Perform Shifting then Inverse Fourier Transform and Display the Magnitude Image**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.imshow(img_back,cmap="gray")
plt.axis("off")
plt.title("Magnitude Spectrum.")
plt.show()

# %% [markdown]
# **UNIT II : Line Detection**

# %% [markdown]
# **STEP I : Read and Display Image in Color and Gray-Scale.**
# > **Supporting Lines of Code :**
# > 1.   **Convert To Gray-Scale :** cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# >

# %%
img = cv2.imread('/content/line.png')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(12,12))

plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.axis("off")
plt.title("Color Image")

plt.subplot(1,2,2)
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("Gray-Scale Image")

plt.show()

# %% [markdown]
# **STEP II : Display the Edges using Canny Edge Detector.**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.imshow(edges,cmap="gray")
plt.axis("off")
plt.title("Edge Image")
plt.show()

# %% [markdown]
# **STEP III : Use Hough Line to get the Lines.**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %% [markdown]
# **STEP IV : Iterate through the lines and convert Polar Coordinate to Cartesian Coordinate, Draw the lines and Display the Image.**

# %%
for i in range(len(lines)):
  r,theta = lines[i][0] 
  a = np.cos(theta) 
  b = np.sin(theta) 
  x0 = a*r 
  y0 = b*r 
  x1 = int(x0 + 1000*(-b)) 
  y1 = int(y0 + 1000*(a)) 
  x2 = int(x0 - 1000*(-b)) 
  y2 = int(y0 - 1000*(a)) 
  cv2.line(img,(x1,y1), (x2,y2), (0,255,0),5)
plt.imshow(img[:,:,::-1])
plt.show()

# %% [markdown]
# **UNIT IV : Circle Detection**

# %% [markdown]
# **STEP I : Read and Display Image in Color and Gray-Scale.**
# > **Supporting Lines of Code :**
# > 1.   **Convert To Gray-Scale :** cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# >

# %%
img = cv2.imread('/content/TED-Circles-Intro-5dc0ad1fdb60cd923fb38f1dfaaa4401.jpg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(12,12))

plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.axis("off")
plt.title("Color Image")

plt.subplot(1,2,2)
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("Gray-Scale Image")

plt.show()

# %% [markdown]
# **STEP II : Blur and Display the Image.**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.imshow(gray_blurred,cmap="gray")
plt.axis("off")
plt.title("Blurred Gray-Scale Image")
plt.show()

# %% [markdown]
# **STEP III : Use Hough Circle to find out the Detected Circles.**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %% [markdown]
# **STEP IV : Draw Circles that are Detected, and display the Final Image.**

# %%
if detected_circles is not None: 
    detected_circles = np.uint16(np.around(detected_circles)) 
    for pt in detected_circles[0, :]: 
        a, b, r = pt[0], pt[1], pt[2] 
        cv2.circle(img, (a, b), r, (255, 255, 0), 15) 
        cv2.circle(img, (a, b), 2, (255, 0, 0), 5) 
plt.imshow(img[:,:,::-1])
plt.show()

# %% [markdown]
# **UNIT V : Harris Corner**

# %% [markdown]
# **STEP I : Read and Display Image in Color and Gray-Scale.**
# > **Supporting Lines of Code :**
# > 1.   **Convert To Gray-Scale :** cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# >

# %%
img = cv2.imread('/content/download.jpeg')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(12,12))

plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.axis("off")
plt.title("Color Image")

plt.subplot(1,2,2)
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("Gray-Scale Image")

plt.show()

# %% [markdown]
# **STEP II : Convert the Gray scale Image into Float32 Image.**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %% [markdown]
# **STEP III : Use Harris Corner to find out the Corners and then Dilate them.**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %% [markdown]
# **STEP IV : Finally Mark the Corners and Display the Image.**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %%
plt.imshow(img[:,:,::-1])
plt.axis("off")
plt.title("Image with Corners Marked.")
plt.show()
