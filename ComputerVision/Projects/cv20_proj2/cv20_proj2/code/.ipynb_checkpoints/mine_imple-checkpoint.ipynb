# %% [markdown]
# ## My implementation

# %%
import cv2
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import time

# %matplotlib inline
from utils import  hough_peaks, hough_lines_draw, hough_circles_draw, preprocess, plotFigure, plotFigureGray
# from student_code

from student_code import hough_lines_vote_acc, hough_circles_vote_acc, find_circles
# %load_ext autoreload
# %autoreload 2

# %%
image0 = cv2.imread('../data/extra/I27.jpg')
plotFigure(image0)

# %%
edge_img = preprocess(image0, 3, 30, 6, 10, 30)  
plotFigureGray(edge_img)

# %%
H, thetas, rhos = hough_lines_vote_acc(edge_img)
# Detect peaks on the hough space of the edge image and highlight them
peaks = hough_peaks(H, numpeaks=10, threshold=70, nhood_size=50)

H_peaks = H.copy()
for peak in peaks:
    cv2.circle(H_peaks, tuple(peak[::-1]), 8, (255,255,255), 1)
cv2.imwrite('../results/I27.png', H_peaks)

# Draw the detected lines on the image

img_lines= image0.copy()
hough_lines_draw(img_lines, '../results/I27_line.png', peaks, rhos, thetas)
# Out:
# array([[[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        [[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        [[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        ...,
#
#        [[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        [[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        [[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]]], dtype=uint8)

# %%
image0 = cv2.imread('../data/extra/I63.jpg')
plotFigure(image0)

# %%
edge_img = preprocess(image0, 3, 30, 6, 10, 30)  
plotFigureGray(edge_img)

# %%
H, thetas, rhos = hough_lines_vote_acc(edge_img)
# Detect peaks on the hough space of the edge image and highlight them
peaks = hough_peaks(H, numpeaks=10, threshold=70, nhood_size=50)

H_peaks = H.copy()
for peak in peaks:
    cv2.circle(H_peaks, tuple(peak[::-1]), 8, (255,255,255), 1)
cv2.imwrite('../results/I63.png', H_peaks)

# Draw the detected lines on the image

img_lines= image0.copy()
hough_lines_draw(img_lines, '../results/I63_line.png', peaks, rhos, thetas)
# Out:
# array([[[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        [[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        [[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        ...,
#
#        [[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        [[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        [[48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]]], dtype=uint8)
