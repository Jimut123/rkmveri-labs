# %% [markdown]
# 1.  **Computer Vision and Pattern Recognition**
# 2.  **CS-342**
# 3.  **Lab_Quiz_01**
# 4.  **Date : 20-01-2020**
# 5.  **Full Marks : 50**
# 6.  **Duration : 30 Minutes.**
#
# ## Save the file as FIRSTNAME_Lab_Quiz_01.ipynb and submit it on Google Classroom. Example: Seshadri_Lab_Quiz_01.ipynb

# %% [markdown]
# **Please fill the following details :**
#
# 1.   **NAME :**
# 2.   **ID :**
# 3.   **STREAM :**

# %% [markdown]
# **IMPORT HEADERS**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# **Question 1 : Draw a White and Black Square each of 400 x 400 x 3 and print its shape.**
#
# **MARKS : 10**

# %% [markdown]
# **Expected Output :**

# %%
# Out:
# The shape of the White-Square is :  (400, 400, 3)
# The shape of the Black-Square is :  (400, 400, 3)

# %% [markdown]
# **Your Code in the Below Cell :**

# %% [markdown]
# **Marks Obtained :**

# %% [markdown]
# **Question 2 : Draw a Red, a Green, and a Blue Square each of shape 200 X 200 X 3 and print its shape.**
#
# **MARKS : 10**

# %% [markdown]
# **Expected Output :**

# %%
# Out:
# The shape of the Red-Square is :  (200, 200, 3)
# The shape of the Green-Square is :  (200, 200, 3)
# The shape of the Blue-Square is :  (200, 200, 3)

# %% [markdown]
# **Your Code in the Below Cell :**

# %% [markdown]
# **Marks Obtained :**

# %% [markdown]
# **Question 3 : Generate a Gaussian Noise of shape 200 X 200 X 3 with mean 0 and sigma 30 for all three channels. Display it, and print its shape.**
#
# **MARKS : 10**

# %% [markdown]
# **Expected Output :**

# %%
# Out:
# The shape of the Gaussian-Noise is :  (200, 200, 3)

# %% [markdown]
# **Your Code in the Below Cell :**

# %% [markdown]
# **Marks Obtained :**

# %% [markdown]
# **Question 4 : Draw a 2 X 2 Square Grid of shape 400 X 400 X 3 with the following specifications :**
#
#
# 1.   **Top-Left Box should be Red in Color.**
# 2.   **Top-Right Box should be Green in Color.**
# 3.   **Bottom-Right Box should be Blue in Color.**
# 4.   **Bottom-Left Box should have the Gaussian Noise**
#
# **Note :** You must use the previously created Red, Green, Blue and the Noise Matrices.
#
# **MARKS : 15**

# %% [markdown]
# **Expected Output :**

# %%
# Out:
# The shape of the 2 x 2 Square-Grid is :  (400, 400, 3)

# %% [markdown]
# **Your Code in the Below Cell :**

# %% [markdown]
# **Marks Obtained :**

# %% [markdown]
# **Question 5 : Save the Previously Created Image with File Name : "/content/RGB_Noise.png"**
#
# **MARKS : 5**

# %% [markdown]
# **Your Code in the Below Cell :**

# %%
# Out:
# True

# %% [markdown]
# **Marks Obtained :**
