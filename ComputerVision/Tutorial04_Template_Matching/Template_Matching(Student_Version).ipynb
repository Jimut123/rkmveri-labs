# %% [markdown]
# ![alt text](https://media1.tenor.com/images/7dcc0b5a2c64d741b6edd12a88738cf9/tenor.gif?itemid=4767352)

# %% [markdown]
# **IMPORT HEADERS**

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# **READ THE IMAGE AND THE TEMPLATE AND DISPLAY, ALSO CONVERT AND DISPLAY THE GRAYSCALE OF THE ORIGINAL IMAGE**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %% [markdown]
# **methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR', 'cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']**

# %% [markdown]
# **NOW USE ALL THE METHODS MENTIONED ABOVE AND DO THE TEMPLATE MATCHING. YOU CAN COPY THE ABOVE LIST OF METHODS.**

# %% [markdown]
# **EXPECTED OUTPUT :**

# %% [markdown]
# **YOUR CODE IN THE BELOW CELL :**

# %% [markdown]
# ![alt text](https://lh3.googleusercontent.com/proxy/txBrpd2shR1ZKafZAblc5lgo8c0b2nJ758bJYDByfA9aZ9d4JF1eIpETMc7iPosUOLvUZC_0O-NR_fs_IRvq56PsoVCBO4q4BfOp7hsmgTBnmUYEZUN8do49gjX3JMWR45I)
