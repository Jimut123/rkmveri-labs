# %% [markdown]
# ## This code captures a whole website and saves it to web archive

# %%
# !wget -m https://jimut123.github.io/
# Out:
# --2020-06-04 02:49:09--  https://jimut123.github.io/
# Resolving jimut123.github.io (jimut123.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to jimut123.github.io (jimut123.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11048 (11K) [text/html]
# Saving to: ‘jimut123.github.io/index.html’
#
# jimut123.github.io/ 100%[===================>]  10.79K  --.-KB/s    in 0s
#
# 2020-06-04 02:49:09 (108 MB/s) - ‘jimut123.github.io/index.html’ saved [11048/11048]
#
# Loading robots.txt; please ignore errors.
# --2020-06-04 02:49:09--  https://jimut123.github.io/robots.txt
# Reusing existing connection to jimut123.github.io:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 66 [text/plain]
# Saving to: ‘jimut123.github.io/robots.txt’
#
# jimut123.github.io/ 100%[===================>]      66  --.-KB/s    in 0s
#
# 2020-06-04 02:49:09 (363 KB/s) - ‘jimut123.github.io/robots.txt’ saved [66/66]
# ...

# %%
! git clone https://github.com/Jimut123/Jimut123.github.io
# Out:
# Cloning into 'Jimut123.github.io'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 3603 (delta 34), reused 22 (delta 7), pack-reused 3547
# Receiving objects: 100% (3603/3603), 725.88 MiB | 34.72 MiB/s, done.
# Resolving deltas: 100% (1211/1211), done.
# Checking out files: 100% (558/558), done.

# %%
# %%capture
# !find . -type f -exec curl -v "https://web.archive.org/save/https://{}" ';'
