# %%
! pip install hiddenlayer graphviz torchviz
# Out:
# Requirement already satisfied: hiddenlayer in /usr/local/lib/python3.6/dist-packages (0.3)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (0.10.1)
# Collecting torchviz
#   Downloading https://files.pythonhosted.org/packages/8f/8e/a9630c7786b846d08b47714dd363a051f5e37b4ea0e534460d8cdfc1644b/torchviz-0.0.1.tar.gz (41kB)
#      |████████████████████████████████| 51kB 2.2MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchviz) (1.6.0+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->torchviz) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->torchviz) (1.18.5)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.1-cp36-none-any.whl size=3520 sha256=ca7ad615a188fcf4865ec3d8f0bdce1c431a43f322315ecd05c99571f98c5fac
#   Stored in directory: /root/.cache/pip/wheels/2a/c2/c5/b8b4d0f7992c735f6db5bfa3c5f354cf36502037ca2b585667
# Successfully built torchviz
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.1

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as Data
from torchvision import datasets, transforms
import torch.nn.functional as F
import timeit
import unittest


torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(0)

# %%
# check availability of GPU and set the device accordingly

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


# define a transforms for preparing the dataset
transform = transforms.Compose([
        transforms.CenterCrop(26),
        transforms.Resize((28,28)),
        transforms.ColorJitter(brightness=0.05, contrast=0.05, saturation=0.05, hue=0.05),
        transforms.RandomRotation(10),      
        transforms.RandomAffine(5),
        transforms.ToTensor(), # convert the image to a pytorch tensor
        transforms.Normalize((0.1307,), (0.3081,)) # normalise the images with mean and std of the dataset
        ])

# %%
# Load the MNIST training, test datasets using `torchvision.datasets.MNIST` using the transform defined above

train_dataset = datasets.MNIST('./data',train=True,transform=transform,download=True)
test_dataset =  datasets.MNIST('./data',train=False,transform=transform,download=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:469: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
# create dataloaders for training and test datasets
# use a batch size of 32 and set shuffle=True for the training set

train_dataloader = Data.DataLoader(dataset=train_dataset, batch_size=128, shuffle=True)
test_dataloader = Data.DataLoader(dataset=test_dataset, batch_size=128, shuffle=True)

# %%
# My Net

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        # define a conv layer with output channels as 16, kernel size of 3 and stride of 1
        self.conv11 = nn.Conv2d(1, 32, 3, 1) # Input = 1x28x28  Output = 32x26x26
        self.conv12 = nn.Conv2d(1, 32, 5, 1) # Input = 1x28x28  Output = 32x24x24
        self.conv13 = nn.Conv2d(1, 32, 7, 1) # Input = 1x28x28  Output = 32x22x22
        self.conv14 = nn.Conv2d(1, 32, 9, 1) # Input = 1x28x28  Output = 32x20x20

        # define a conv layer with output channels as 32, kernel size of 3 and stride of 1
        self.conv21 = nn.Conv2d(32, 64, 3, 1) # Input = 32x26x26 Output = 64x24x24
        self.conv22 = nn.Conv2d(32, 64, 5, 1) # Input = 32x24x24 Output = 64x20x20
        self.conv23 = nn.Conv2d(32, 64, 7, 1) # Input = 32x22x22 Output = 64x16x16
        self.conv24 = nn.Conv2d(32, 64, 9, 1) # Input = 32x20x20  Output = 64x12x12

        # define a conv layer with output channels as 64, kernel size of 3 and stride of 1
        self.conv31 = nn.Conv2d(64, 128, 3, 1) # Input = 64x24x24 Output = 128x22x22
        self.conv32 = nn.Conv2d(64, 128, 5, 1) # Input = 64x20x20 Output = 128x16x16
        self.conv33 = nn.Conv2d(64, 128, 7, 1) # Input = 64x16x16 Output = 128x10x10
        self.conv34 = nn.Conv2d(64, 128, 9, 1) # Input = 64x12x12 Output = 128x4x4
        

        # define a max pooling layer with kernel size 2
        self.maxpool = nn.MaxPool2d(2) # Output = 64x11x11
        #self.maxpool1 = nn.MaxPool2d(1)
        # define dropout layer with a probability of 0.25
        self.dropout1 = nn.Dropout(0.25)
        # define dropout layer with a probability of 0.5
        self.dropout2 = nn.Dropout(0.5)

        # define a linear(dense) layer with 128 output features
        self.fc11 = nn.Linear(128*11*11, 256)
        self.fc12 = nn.Linear(128*8*8, 256)      # after maxpooling 2x2
        self.fc13 = nn.Linear(128*5*5, 256)
        self.fc14 = nn.Linear(128*2*2, 256)

        # define a linear(dense) layer with output features corresponding to the number of classes in the dataset
        self.fc21 = nn.Linear(256, 128)
        self.fc22 = nn.Linear(256, 128)
        self.fc23 = nn.Linear(256, 128)
        self.fc24 = nn.Linear(256, 128)

        self.fc33 = nn.Linear(128*4,10)
        #self.fc33 = nn.Linear(64*3,10)
        

    def forward(self, inp):
        # Use the layers defined above in a sequential way (folow the same as the layer definitions above) and 
        # write the forward pass, after each of conv1, conv2, conv3 and fc1 use a relu activation. 
        

        x = F.relu(self.conv11(inp))
        x = F.relu(self.conv21(x))
        x = F.relu(self.maxpool(self.conv31(x)))
        #print(x.shape)
        #x = torch.flatten(x, 1)
        x = x.view(-1,128*11*11)
        x = self.dropout1(x)
        x = F.relu(self.fc11(x))
        x = self.dropout2(x)
        x = self.fc21(x)

        y = F.relu(self.conv12(inp))
        y = F.relu(self.conv22(y))
        y = F.relu(self.maxpool(self.conv32(y)))
        #x = torch.flatten(x, 1)
        y = y.view(-1,128*8*8)
        y = self.dropout1(y)
        y = F.relu(self.fc12(y))
        y = self.dropout2(y)
        y = self.fc22(y)

        z = F.relu(self.conv13(inp))
        z = F.relu(self.conv23(z))
        z = F.relu(self.maxpool(self.conv33(z)))
        #x = torch.flatten(x, 1)
        z = z.view(-1,128*5*5)
        z = self.dropout1(z)
        z = F.relu(self.fc13(z))
        z = self.dropout2(z)
        z = self.fc23(z)

        ze = F.relu(self.conv14(inp))
        ze = F.relu(self.conv24(ze))
        ze = F.relu(self.maxpool(self.conv34(ze)))
        #x = torch.flatten(x, 1)
        ze = ze.view(-1,128*2*2)
        ze = self.dropout1(ze)
        ze = F.relu(self.fc14(ze))
        ze = self.dropout2(ze)
        ze = self.fc24(ze)

        out_f = torch.cat((x, y, z, ze), dim=1)
        #out_f1 = torch.cat((out_f, ze), dim=1)
        out = self.fc33(out_f)
        
        output = F.log_softmax(out, dim=1)
        return output

# %%
torch.cat((torch.tensor([1,2]),torch.tensor([2,3]),torch.tensor([3,4]),torch.tensor([3,4])),dim=0)
# Out:
# tensor([1, 2, 2, 3, 3, 4, 3, 4])

# %%
torch.tensor(1)
# Out:
# tensor(1)

# %%
model = Net().to(device)

# %%
print(model.parameters)
# Out:
# <bound method Module.parameters of Net(
#   (conv11): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv12): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv13): Conv2d(1, 32, kernel_size=(7, 7), stride=(1, 1))
#   (conv14): Conv2d(1, 32, kernel_size=(9, 9), stride=(1, 1))
#   (conv21): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv22): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (conv23): Conv2d(32, 64, kernel_size=(7, 7), stride=(1, 1))
#   (conv24): Conv2d(32, 64, kernel_size=(9, 9), stride=(1, 1))
#   (conv31): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv32): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1))
#   (conv33): Conv2d(64, 128, kernel_size=(7, 7), stride=(1, 1))
#   (conv34): Conv2d(64, 128, kernel_size=(9, 9), stride=(1, 1))
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc11): Linear(in_features=15488, out_features=256, bias=True)
#   (fc12): Linear(in_features=8192, out_features=256, bias=True)
#   (fc13): Linear(in_features=3200, out_features=256, bias=True)
#   (fc14): Linear(in_features=512, out_features=256, bias=True)
#   (fc21): Linear(in_features=256, out_features=128, bias=True)
#   (fc22): Linear(in_features=256, out_features=128, bias=True)
#   (fc23): Linear(in_features=256, out_features=128, bias=True)
#   (fc24): Linear(in_features=256, out_features=128, bias=True)
#   (fc33): Linear(in_features=512, out_features=10, bias=True)
# )>

# %%
import unittest

class TestImplementations(unittest.TestCase):
    
    # Dataloading tests
    def test_dataset(self):
        self.dataset_classes = ['0 - zero',
                                '1 - one',
                                '2 - two',
                                '3 - three',
                                '4 - four',
                                '5 - five',
                                '6 - six',
                                '7 - seven',
                                '8 - eight',
                                '9 - nine']
        self.assertTrue(train_dataset.classes == self.dataset_classes)
        self.assertTrue(train_dataset.train == True)
    
    def test_dataloader(self):        
        self.assertTrue(train_dataloader.batch_size == 32)
        self.assertTrue(test_dataloader.batch_size == 32)      
         
    def test_total_parameters(self):
        model = Net().to(device)
        #self.assertTrue(sum(p.numel() for p in model.parameters()) == 1015946)

suite = unittest.TestLoader().loadTestsFromModule(TestImplementations())
unittest.TextTestRunner().run(suite)
# Out:
# F..
# ======================================================================
# FAIL: test_dataloader (__main__.TestImplementations)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-10-80e7f3fdfcef>", line 21, in test_dataloader
#     self.assertTrue(train_dataloader.batch_size == 32)
# AssertionError: False is not true
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.077s
#
# FAILED (failures=1)
# <unittest.runner.TextTestResult run=3 errors=0 failures=1>

# %%
losses_1 = []
losses_2 = []

def train(model, device, train_loader, optimizer, epoch):
    model.train()
    
    for batch_idx, (data, target) in enumerate(train_loader):
        # send the image, target to the device
        data, target = data.to(device), target.to(device)
        # flush out the gradients stored in optimizer
        optimizer.zero_grad()
        # pass the image to the model and assign the output to variable named output
        output = model(data)
        # calculate the loss (use nll_loss in pytorch)
        loss = F.nll_loss(output, target)
        # do a backward pass
        loss.backward()
        # update the weights
        optimizer.step()
      
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
            losses_1.append(loss.item())
            losses_2.append(100. * batch_idx / len(train_loader))

# %%
accuracy = []
avg_loss = []
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
          
            # send the image, target to the device
            data, target = data.to(device), target.to(device)
            # pass the image to the model and assign the output to variable named output
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
          
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    avg_loss.append(test_loss)
    accuracy.append(100. * correct / len(test_loader.dataset))

# %%
model = Net().to(device)

def init_weights(m):
  if isinstance(m, nn.Conv2d) or isinstance(m,nn.Linear):
    torch.nn.init.xavier_normal(m.weight)
    torch.nn.init.zeros_(m.bias)

model.apply(init_weights)  

learning_rate = []
def adjust_learning_rate(optimizer, iter, each):
    # sets the learning rate to the initial LR decayed by 0.1 every 'each' iterations
    lr = 0.001 * (0.95 ** (iter // each))
    state_dict = optimizer.state_dict()
    for param_group in state_dict['param_groups']:
        param_group['lr'] = lr
    optimizer.load_state_dict(state_dict)
    print("Learning rate = ",lr)
    return lr


## Define Adam Optimiser with a learning rate of 0.01
optimizer =  torch.optim.Adagrad(model.parameters(),lr=0.01)

start = timeit.default_timer()
for epoch in range(1,100):
  lr = adjust_learning_rate(optimizer, epoch, 1.616)
  learning_rate.append(lr)
  train(model, device, train_dataloader, optimizer, epoch)
  test(model, device, test_dataloader)
stop = timeit.default_timer()
print('Total time taken: {} seconds'.format(int(stop - start)))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: UserWarning: nn.init.xavier_normal is now deprecated in favor of nn.init.xavier_normal_.
# Learning rate =  0.001
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.347040
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.308560
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.104325
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.252981
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.169814
#
# Test set: Average loss: 0.0694, Accuracy: 9777/10000 (98%)
#
# Learning rate =  0.00095
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.097548
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.107923
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.066878
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.101566
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.027795
#
# Test set: Average loss: 0.0500, Accuracy: 9834/10000 (98%)
#
# Learning rate =  0.00095
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.065325
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.038646
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.028840
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.060622
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.029841
#
# Test set: Average loss: 0.0423, Accuracy: 9861/10000 (99%)
#
# Learning rate =  0.0009025
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.040098
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.057783
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.057809
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.048361
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.069359
#
# Test set: Average loss: 0.0404, Accuracy: 9872/10000 (99%)
#
# Learning rate =  0.000857375
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.077632
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.031845
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.046750
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.065783
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.061333
#
# Test set: Average loss: 0.0344, Accuracy: 9886/10000 (99%)
#
# Learning rate =  0.000857375
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.041345
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.073732
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.048701
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.024053
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.041195
#
# Test set: Average loss: 0.0361, Accuracy: 9878/10000 (99%)
#
# Learning rate =  0.0008145062499999999
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.026287
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.055567
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.035072
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.034880
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.038809
#
# Test set: Average loss: 0.0316, Accuracy: 9900/10000 (99%)
#
# Learning rate =  0.0008145062499999999
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.062946
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.016653
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.039156
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.043167
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.013643
#
# Test set: Average loss: 0.0357, Accuracy: 9885/10000 (99%)
#
# Learning rate =  0.0007737809374999998
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.025192
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.051072
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.038502
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.065390
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.054109
#
# Test set: Average loss: 0.0305, Accuracy: 9890/10000 (99%)
#
# Learning rate =  0.0007350918906249999
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.038473
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 0.048878
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.019878
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 0.038896
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.022870
#
# Test set: Average loss: 0.0293, Accuracy: 9900/10000 (99%)
#
# Learning rate =  0.0007350918906249999
# Train Epoch: 11 [0/60000 (0%)]	Loss: 0.016209
# Train Epoch: 11 [12800/60000 (21%)]	Loss: 0.156481
# Train Epoch: 11 [25600/60000 (43%)]	Loss: 0.020287
# Train Epoch: 11 [38400/60000 (64%)]	Loss: 0.005916
# Train Epoch: 11 [51200/60000 (85%)]	Loss: 0.015512
#
# Test set: Average loss: 0.0291, Accuracy: 9908/10000 (99%)
#
# Learning rate =  0.0006983372960937497
# Train Epoch: 12 [0/60000 (0%)]	Loss: 0.035934
# Train Epoch: 12 [12800/60000 (21%)]	Loss: 0.017044
# Train Epoch: 12 [25600/60000 (43%)]	Loss: 0.020659
# Train Epoch: 12 [38400/60000 (64%)]	Loss: 0.032012
# Train Epoch: 12 [51200/60000 (85%)]	Loss: 0.037137
#
# Test set: Average loss: 0.0262, Accuracy: 9907/10000 (99%)
#
# Learning rate =  0.0006634204312890623
# Train Epoch: 13 [0/60000 (0%)]	Loss: 0.047005
# Train Epoch: 13 [12800/60000 (21%)]	Loss: 0.039225
# Train Epoch: 13 [25600/60000 (43%)]	Loss: 0.024211
# Train Epoch: 13 [38400/60000 (64%)]	Loss: 0.025584
# Train Epoch: 13 [51200/60000 (85%)]	Loss: 0.039455
#
# Test set: Average loss: 0.0266, Accuracy: 9902/10000 (99%)
#
# Learning rate =  0.0006634204312890623
# Train Epoch: 14 [0/60000 (0%)]	Loss: 0.011741
# Train Epoch: 14 [12800/60000 (21%)]	Loss: 0.029115
# Train Epoch: 14 [25600/60000 (43%)]	Loss: 0.028343
# Train Epoch: 14 [38400/60000 (64%)]	Loss: 0.038703
# Train Epoch: 14 [51200/60000 (85%)]	Loss: 0.029366
#
# Test set: Average loss: 0.0293, Accuracy: 9904/10000 (99%)
#
# Learning rate =  0.0006302494097246091
# Train Epoch: 15 [0/60000 (0%)]	Loss: 0.052663
# Train Epoch: 15 [12800/60000 (21%)]	Loss: 0.007014
# Train Epoch: 15 [25600/60000 (43%)]	Loss: 0.011643
# Train Epoch: 15 [38400/60000 (64%)]	Loss: 0.038305
# Train Epoch: 15 [51200/60000 (85%)]	Loss: 0.008331
#
# Test set: Average loss: 0.0262, Accuracy: 9915/10000 (99%)
#
# Learning rate =  0.0006302494097246091
# Train Epoch: 16 [0/60000 (0%)]	Loss: 0.021036
# Train Epoch: 16 [12800/60000 (21%)]	Loss: 0.021229
# Train Epoch: 16 [25600/60000 (43%)]	Loss: 0.065458
# Train Epoch: 16 [38400/60000 (64%)]	Loss: 0.051615
# Train Epoch: 16 [51200/60000 (85%)]	Loss: 0.051041
#
# Test set: Average loss: 0.0253, Accuracy: 9909/10000 (99%)
#
# Learning rate =  0.0005987369392383787
# Train Epoch: 17 [0/60000 (0%)]	Loss: 0.037998
# Train Epoch: 17 [12800/60000 (21%)]	Loss: 0.065123
# Train Epoch: 17 [25600/60000 (43%)]	Loss: 0.012108
# Train Epoch: 17 [38400/60000 (64%)]	Loss: 0.012410
# Train Epoch: 17 [51200/60000 (85%)]	Loss: 0.087365
#
# Test set: Average loss: 0.0263, Accuracy: 9913/10000 (99%)
#
# Learning rate =  0.0005688000922764596
# Train Epoch: 18 [0/60000 (0%)]	Loss: 0.015367
# Train Epoch: 18 [12800/60000 (21%)]	Loss: 0.012237
# Train Epoch: 18 [25600/60000 (43%)]	Loss: 0.011259
# Train Epoch: 18 [38400/60000 (64%)]	Loss: 0.045045
# Train Epoch: 18 [51200/60000 (85%)]	Loss: 0.003632
#
# Test set: Average loss: 0.0247, Accuracy: 9918/10000 (99%)
#
# Learning rate =  0.0005688000922764596
# Train Epoch: 19 [0/60000 (0%)]	Loss: 0.074306
# Train Epoch: 19 [12800/60000 (21%)]	Loss: 0.037461
# Train Epoch: 19 [25600/60000 (43%)]	Loss: 0.005262
# Train Epoch: 19 [38400/60000 (64%)]	Loss: 0.016674
# Train Epoch: 19 [51200/60000 (85%)]	Loss: 0.021962
#
# Test set: Average loss: 0.0241, Accuracy: 9913/10000 (99%)
#
# Learning rate =  0.0005403600876626366
# Train Epoch: 20 [0/60000 (0%)]	Loss: 0.008325
# Train Epoch: 20 [12800/60000 (21%)]	Loss: 0.023434
# Train Epoch: 20 [25600/60000 (43%)]	Loss: 0.005306
# Train Epoch: 20 [38400/60000 (64%)]	Loss: 0.051738
# Train Epoch: 20 [51200/60000 (85%)]	Loss: 0.109288
#
# Test set: Average loss: 0.0243, Accuracy: 9912/10000 (99%)
#
# Learning rate =  0.0005403600876626366
# Train Epoch: 21 [0/60000 (0%)]	Loss: 0.006929
# Train Epoch: 21 [12800/60000 (21%)]	Loss: 0.013417
# Train Epoch: 21 [25600/60000 (43%)]	Loss: 0.008647
# Train Epoch: 21 [38400/60000 (64%)]	Loss: 0.010149
# Train Epoch: 21 [51200/60000 (85%)]	Loss: 0.050668
#
# Test set: Average loss: 0.0251, Accuracy: 9913/10000 (99%)
#
# Learning rate =  0.0005133420832795048
# Train Epoch: 22 [0/60000 (0%)]	Loss: 0.113174
# Train Epoch: 22 [12800/60000 (21%)]	Loss: 0.065029
# Train Epoch: 22 [25600/60000 (43%)]	Loss: 0.018386
# Train Epoch: 22 [38400/60000 (64%)]	Loss: 0.014654
# Train Epoch: 22 [51200/60000 (85%)]	Loss: 0.013923
#
# Test set: Average loss: 0.0226, Accuracy: 9923/10000 (99%)
#
# Learning rate =  0.00048767497911552955
# Train Epoch: 23 [0/60000 (0%)]	Loss: 0.009886
# Train Epoch: 23 [12800/60000 (21%)]	Loss: 0.017389
# Train Epoch: 23 [25600/60000 (43%)]	Loss: 0.107754
# Train Epoch: 23 [38400/60000 (64%)]	Loss: 0.038066
# Train Epoch: 23 [51200/60000 (85%)]	Loss: 0.011151
#
# Test set: Average loss: 0.0232, Accuracy: 9917/10000 (99%)
#
# Learning rate =  0.00048767497911552955
# Train Epoch: 24 [0/60000 (0%)]	Loss: 0.005050
# Train Epoch: 24 [12800/60000 (21%)]	Loss: 0.037707
# Train Epoch: 24 [25600/60000 (43%)]	Loss: 0.004777
# Train Epoch: 24 [38400/60000 (64%)]	Loss: 0.019318
# Train Epoch: 24 [51200/60000 (85%)]	Loss: 0.036130
#
# Test set: Average loss: 0.0235, Accuracy: 9915/10000 (99%)
#
# Learning rate =  0.000463291230159753
# Train Epoch: 25 [0/60000 (0%)]	Loss: 0.009735
# Train Epoch: 25 [12800/60000 (21%)]	Loss: 0.018801
# Train Epoch: 25 [25600/60000 (43%)]	Loss: 0.004170
# Train Epoch: 25 [38400/60000 (64%)]	Loss: 0.014088
# Train Epoch: 25 [51200/60000 (85%)]	Loss: 0.044373
#
# Test set: Average loss: 0.0220, Accuracy: 9924/10000 (99%)
#
# Learning rate =  0.00044012666865176535
# Train Epoch: 26 [0/60000 (0%)]	Loss: 0.024901
# Train Epoch: 26 [12800/60000 (21%)]	Loss: 0.006287
# Train Epoch: 26 [25600/60000 (43%)]	Loss: 0.029365
# Train Epoch: 26 [38400/60000 (64%)]	Loss: 0.022919
# Train Epoch: 26 [51200/60000 (85%)]	Loss: 0.004225
#
# Test set: Average loss: 0.0230, Accuracy: 9913/10000 (99%)
#
# Learning rate =  0.00044012666865176535
# Train Epoch: 27 [0/60000 (0%)]	Loss: 0.079025
# Train Epoch: 27 [12800/60000 (21%)]	Loss: 0.048261
# Train Epoch: 27 [25600/60000 (43%)]	Loss: 0.039513
# Train Epoch: 27 [38400/60000 (64%)]	Loss: 0.009814
# Train Epoch: 27 [51200/60000 (85%)]	Loss: 0.007186
#
# Test set: Average loss: 0.0236, Accuracy: 9918/10000 (99%)
#
# Learning rate =  0.0004181203352191771
# Train Epoch: 28 [0/60000 (0%)]	Loss: 0.011960
# Train Epoch: 28 [12800/60000 (21%)]	Loss: 0.018409
# Train Epoch: 28 [25600/60000 (43%)]	Loss: 0.015529
# Train Epoch: 28 [38400/60000 (64%)]	Loss: 0.015852
# Train Epoch: 28 [51200/60000 (85%)]	Loss: 0.002298
#
# Test set: Average loss: 0.0227, Accuracy: 9918/10000 (99%)
#
# Learning rate =  0.0004181203352191771
# Train Epoch: 29 [0/60000 (0%)]	Loss: 0.033510
# Train Epoch: 29 [12800/60000 (21%)]	Loss: 0.028005
# Train Epoch: 29 [25600/60000 (43%)]	Loss: 0.015687
# Train Epoch: 29 [38400/60000 (64%)]	Loss: 0.001472
# Train Epoch: 29 [51200/60000 (85%)]	Loss: 0.018506
#
# Test set: Average loss: 0.0220, Accuracy: 9922/10000 (99%)
#
# Learning rate =  0.0003972143184582182
# Train Epoch: 30 [0/60000 (0%)]	Loss: 0.025807
# Train Epoch: 30 [12800/60000 (21%)]	Loss: 0.045608
# Train Epoch: 30 [25600/60000 (43%)]	Loss: 0.050520
# Train Epoch: 30 [38400/60000 (64%)]	Loss: 0.037805
# Train Epoch: 30 [51200/60000 (85%)]	Loss: 0.029396
#
# Test set: Average loss: 0.0221, Accuracy: 9922/10000 (99%)
#
# Learning rate =  0.00037735360253530727
# Train Epoch: 31 [0/60000 (0%)]	Loss: 0.071904
# Train Epoch: 31 [12800/60000 (21%)]	Loss: 0.019088
# Train Epoch: 31 [25600/60000 (43%)]	Loss: 0.032007
# Train Epoch: 31 [38400/60000 (64%)]	Loss: 0.008402
# Train Epoch: 31 [51200/60000 (85%)]	Loss: 0.040322
#
# Test set: Average loss: 0.0240, Accuracy: 9913/10000 (99%)
#
# Learning rate =  0.00037735360253530727
# Train Epoch: 32 [0/60000 (0%)]	Loss: 0.025884
# Train Epoch: 32 [12800/60000 (21%)]	Loss: 0.074191
# Train Epoch: 32 [25600/60000 (43%)]	Loss: 0.021295
# Train Epoch: 32 [38400/60000 (64%)]	Loss: 0.013441
# Train Epoch: 32 [51200/60000 (85%)]	Loss: 0.047261
#
# Test set: Average loss: 0.0227, Accuracy: 9925/10000 (99%)
#
# Learning rate =  0.0003584859224085419
# Train Epoch: 33 [0/60000 (0%)]	Loss: 0.089639
# Train Epoch: 33 [12800/60000 (21%)]	Loss: 0.008040
# Train Epoch: 33 [25600/60000 (43%)]	Loss: 0.007742
# Train Epoch: 33 [38400/60000 (64%)]	Loss: 0.007151
# Train Epoch: 33 [51200/60000 (85%)]	Loss: 0.108499
#
# Test set: Average loss: 0.0221, Accuracy: 9924/10000 (99%)
#
# Learning rate =  0.0003405616262881148
# Train Epoch: 34 [0/60000 (0%)]	Loss: 0.015419
# Train Epoch: 34 [12800/60000 (21%)]	Loss: 0.027789
# Train Epoch: 34 [25600/60000 (43%)]	Loss: 0.040189
# Train Epoch: 34 [38400/60000 (64%)]	Loss: 0.068410
# Train Epoch: 34 [51200/60000 (85%)]	Loss: 0.025055
#
# Test set: Average loss: 0.0236, Accuracy: 9918/10000 (99%)
#
# Learning rate =  0.0003405616262881148
# Train Epoch: 35 [0/60000 (0%)]	Loss: 0.043664
# Train Epoch: 35 [12800/60000 (21%)]	Loss: 0.061824
# Train Epoch: 35 [25600/60000 (43%)]	Loss: 0.006097
# Train Epoch: 35 [38400/60000 (64%)]	Loss: 0.014382
# Train Epoch: 35 [51200/60000 (85%)]	Loss: 0.006277
#
# Test set: Average loss: 0.0221, Accuracy: 9917/10000 (99%)
#
# Learning rate =  0.000323533544973709
# Train Epoch: 36 [0/60000 (0%)]	Loss: 0.012563
# Train Epoch: 36 [12800/60000 (21%)]	Loss: 0.017406
# Train Epoch: 36 [25600/60000 (43%)]	Loss: 0.026819
# Train Epoch: 36 [38400/60000 (64%)]	Loss: 0.012856
# Train Epoch: 36 [51200/60000 (85%)]	Loss: 0.009616
#
# Test set: Average loss: 0.0228, Accuracy: 9916/10000 (99%)
#
# Learning rate =  0.000323533544973709
# Train Epoch: 37 [0/60000 (0%)]	Loss: 0.004933
# Train Epoch: 37 [12800/60000 (21%)]	Loss: 0.032584
# Train Epoch: 37 [25600/60000 (43%)]	Loss: 0.063711
# Train Epoch: 37 [38400/60000 (64%)]	Loss: 0.006099
# Train Epoch: 37 [51200/60000 (85%)]	Loss: 0.004900
#
# Test set: Average loss: 0.0227, Accuracy: 9923/10000 (99%)
#
# Learning rate =  0.00030735686772502356
# Train Epoch: 38 [0/60000 (0%)]	Loss: 0.006910
# Train Epoch: 38 [12800/60000 (21%)]	Loss: 0.037599
# Train Epoch: 38 [25600/60000 (43%)]	Loss: 0.020438
# Train Epoch: 38 [38400/60000 (64%)]	Loss: 0.004598
# Train Epoch: 38 [51200/60000 (85%)]	Loss: 0.013690
#
# Test set: Average loss: 0.0214, Accuracy: 9925/10000 (99%)
#
# Learning rate =  0.0002919890243387724
# Train Epoch: 39 [0/60000 (0%)]	Loss: 0.004750
# Train Epoch: 39 [12800/60000 (21%)]	Loss: 0.022676
# Train Epoch: 39 [25600/60000 (43%)]	Loss: 0.022719
# Train Epoch: 39 [38400/60000 (64%)]	Loss: 0.009672
# Train Epoch: 39 [51200/60000 (85%)]	Loss: 0.036187
#
# Test set: Average loss: 0.0226, Accuracy: 9924/10000 (99%)
#
# Learning rate =  0.0002919890243387724
# Train Epoch: 40 [0/60000 (0%)]	Loss: 0.024534
# Train Epoch: 40 [12800/60000 (21%)]	Loss: 0.021040
# Train Epoch: 40 [25600/60000 (43%)]	Loss: 0.005557
# Train Epoch: 40 [38400/60000 (64%)]	Loss: 0.024632
# Train Epoch: 40 [51200/60000 (85%)]	Loss: 0.027063
#
# Test set: Average loss: 0.0222, Accuracy: 9923/10000 (99%)
#
# Learning rate =  0.00027738957312183375
# Train Epoch: 41 [0/60000 (0%)]	Loss: 0.015617
# Train Epoch: 41 [12800/60000 (21%)]	Loss: 0.031015
# Train Epoch: 41 [25600/60000 (43%)]	Loss: 0.007270
# Train Epoch: 41 [38400/60000 (64%)]	Loss: 0.040050
# Train Epoch: 41 [51200/60000 (85%)]	Loss: 0.028484
#
# Test set: Average loss: 0.0213, Accuracy: 9924/10000 (99%)
#
# Learning rate =  0.00027738957312183375
# Train Epoch: 42 [0/60000 (0%)]	Loss: 0.058776
# Train Epoch: 42 [12800/60000 (21%)]	Loss: 0.013338
# Train Epoch: 42 [25600/60000 (43%)]	Loss: 0.004845
# Train Epoch: 42 [38400/60000 (64%)]	Loss: 0.022421
# Train Epoch: 42 [51200/60000 (85%)]	Loss: 0.034528
#
# Test set: Average loss: 0.0213, Accuracy: 9925/10000 (99%)
#
# Learning rate =  0.00026352009446574203
# Train Epoch: 43 [0/60000 (0%)]	Loss: 0.003728
# Train Epoch: 43 [12800/60000 (21%)]	Loss: 0.010786
# Train Epoch: 43 [25600/60000 (43%)]	Loss: 0.025856
# Train Epoch: 43 [38400/60000 (64%)]	Loss: 0.023794
# Train Epoch: 43 [51200/60000 (85%)]	Loss: 0.022124
#
# Test set: Average loss: 0.0238, Accuracy: 9924/10000 (99%)
#
# Learning rate =  0.00025034408974245495
# Train Epoch: 44 [0/60000 (0%)]	Loss: 0.021409
# Train Epoch: 44 [12800/60000 (21%)]	Loss: 0.035156
# Train Epoch: 44 [25600/60000 (43%)]	Loss: 0.045527
# Train Epoch: 44 [38400/60000 (64%)]	Loss: 0.010553
# Train Epoch: 44 [51200/60000 (85%)]	Loss: 0.033836
#
# Test set: Average loss: 0.0231, Accuracy: 9921/10000 (99%)
#
# Learning rate =  0.00025034408974245495
# Train Epoch: 45 [0/60000 (0%)]	Loss: 0.028108
# Train Epoch: 45 [12800/60000 (21%)]	Loss: 0.025301
# Train Epoch: 45 [25600/60000 (43%)]	Loss: 0.002259
# Train Epoch: 45 [38400/60000 (64%)]	Loss: 0.010276
# Train Epoch: 45 [51200/60000 (85%)]	Loss: 0.020067
#
# Test set: Average loss: 0.0232, Accuracy: 9916/10000 (99%)
#
# Learning rate =  0.00023782688525533216
# Train Epoch: 46 [0/60000 (0%)]	Loss: 0.018171
# Train Epoch: 46 [12800/60000 (21%)]	Loss: 0.016290
# Train Epoch: 46 [25600/60000 (43%)]	Loss: 0.032507
# Train Epoch: 46 [38400/60000 (64%)]	Loss: 0.015568
# Train Epoch: 46 [51200/60000 (85%)]	Loss: 0.006935
#
# Test set: Average loss: 0.0213, Accuracy: 9929/10000 (99%)
#
# Learning rate =  0.00022593554099256555
# Train Epoch: 47 [0/60000 (0%)]	Loss: 0.008468
# Train Epoch: 47 [12800/60000 (21%)]	Loss: 0.013701
# Train Epoch: 47 [25600/60000 (43%)]	Loss: 0.015648
# Train Epoch: 47 [38400/60000 (64%)]	Loss: 0.005956
# Train Epoch: 47 [51200/60000 (85%)]	Loss: 0.020319
#
# Test set: Average loss: 0.0217, Accuracy: 9922/10000 (99%)
#
# Learning rate =  0.00022593554099256555
# Train Epoch: 48 [0/60000 (0%)]	Loss: 0.004634
# Train Epoch: 48 [12800/60000 (21%)]	Loss: 0.011042
# Train Epoch: 48 [25600/60000 (43%)]	Loss: 0.011597
# Train Epoch: 48 [38400/60000 (64%)]	Loss: 0.022444
# Train Epoch: 48 [51200/60000 (85%)]	Loss: 0.028078
#
# Test set: Average loss: 0.0230, Accuracy: 9920/10000 (99%)
#
# Learning rate =  0.00021463876394293727
# Train Epoch: 49 [0/60000 (0%)]	Loss: 0.036517
# Train Epoch: 49 [12800/60000 (21%)]	Loss: 0.010408
# Train Epoch: 49 [25600/60000 (43%)]	Loss: 0.005418
# Train Epoch: 49 [38400/60000 (64%)]	Loss: 0.012977
# Train Epoch: 49 [51200/60000 (85%)]	Loss: 0.032553
#
# Test set: Average loss: 0.0202, Accuracy: 9931/10000 (99%)
#
# Learning rate =  0.00021463876394293727
# Train Epoch: 50 [0/60000 (0%)]	Loss: 0.021774
# Train Epoch: 50 [12800/60000 (21%)]	Loss: 0.013755
# Train Epoch: 50 [25600/60000 (43%)]	Loss: 0.004961
# Train Epoch: 50 [38400/60000 (64%)]	Loss: 0.004968
# Train Epoch: 50 [51200/60000 (85%)]	Loss: 0.012985
#
# Test set: Average loss: 0.0227, Accuracy: 9921/10000 (99%)
#
# Learning rate =  0.00020390682574579038
# Train Epoch: 51 [0/60000 (0%)]	Loss: 0.004761
# Train Epoch: 51 [12800/60000 (21%)]	Loss: 0.004299
# Train Epoch: 51 [25600/60000 (43%)]	Loss: 0.032115
# Train Epoch: 51 [38400/60000 (64%)]	Loss: 0.059278
# Train Epoch: 51 [51200/60000 (85%)]	Loss: 0.007816
#
# Test set: Average loss: 0.0208, Accuracy: 9921/10000 (99%)
#
# Learning rate =  0.00019371148445850088
# Train Epoch: 52 [0/60000 (0%)]	Loss: 0.008654
# Train Epoch: 52 [12800/60000 (21%)]	Loss: 0.005972
# Train Epoch: 52 [25600/60000 (43%)]	Loss: 0.089977
# Train Epoch: 52 [38400/60000 (64%)]	Loss: 0.016187
# Train Epoch: 52 [51200/60000 (85%)]	Loss: 0.065309
#
# Test set: Average loss: 0.0203, Accuracy: 9927/10000 (99%)
#
# Learning rate =  0.00019371148445850088
# Train Epoch: 53 [0/60000 (0%)]	Loss: 0.076086
# Train Epoch: 53 [12800/60000 (21%)]	Loss: 0.035834
# Train Epoch: 53 [25600/60000 (43%)]	Loss: 0.030804
# Train Epoch: 53 [38400/60000 (64%)]	Loss: 0.007776
# Train Epoch: 53 [51200/60000 (85%)]	Loss: 0.005754
#
# Test set: Average loss: 0.0207, Accuracy: 9924/10000 (99%)
#
# Learning rate =  0.00018402591023557584
# Train Epoch: 54 [0/60000 (0%)]	Loss: 0.031479
# Train Epoch: 54 [12800/60000 (21%)]	Loss: 0.005288
# Train Epoch: 54 [25600/60000 (43%)]	Loss: 0.013757
# Train Epoch: 54 [38400/60000 (64%)]	Loss: 0.018432
# Train Epoch: 54 [51200/60000 (85%)]	Loss: 0.047286
#
# Test set: Average loss: 0.0218, Accuracy: 9920/10000 (99%)
#
# Learning rate =  0.000174824614723797
# Train Epoch: 55 [0/60000 (0%)]	Loss: 0.034324
# Train Epoch: 55 [12800/60000 (21%)]	Loss: 0.036087
# Train Epoch: 55 [25600/60000 (43%)]	Loss: 0.018241
# Train Epoch: 55 [38400/60000 (64%)]	Loss: 0.056304
# Train Epoch: 55 [51200/60000 (85%)]	Loss: 0.011939
#
# Test set: Average loss: 0.0223, Accuracy: 9920/10000 (99%)
#
# Learning rate =  0.000174824614723797
# Train Epoch: 56 [0/60000 (0%)]	Loss: 0.016432
# Train Epoch: 56 [12800/60000 (21%)]	Loss: 0.031538
# Train Epoch: 56 [25600/60000 (43%)]	Loss: 0.013327
# Train Epoch: 56 [38400/60000 (64%)]	Loss: 0.068987
# Train Epoch: 56 [51200/60000 (85%)]	Loss: 0.018207
#
# Test set: Average loss: 0.0227, Accuracy: 9919/10000 (99%)
#
# Learning rate =  0.00016608338398760718
# Train Epoch: 57 [0/60000 (0%)]	Loss: 0.005869
# Train Epoch: 57 [12800/60000 (21%)]	Loss: 0.004048
# Train Epoch: 57 [25600/60000 (43%)]	Loss: 0.060554
# Train Epoch: 57 [38400/60000 (64%)]	Loss: 0.010610
# Train Epoch: 57 [51200/60000 (85%)]	Loss: 0.035669
#
# Test set: Average loss: 0.0219, Accuracy: 9925/10000 (99%)
#
# Learning rate =  0.00016608338398760718
# Train Epoch: 58 [0/60000 (0%)]	Loss: 0.035717
# Train Epoch: 58 [12800/60000 (21%)]	Loss: 0.033707
# Train Epoch: 58 [25600/60000 (43%)]	Loss: 0.030355
# Train Epoch: 58 [38400/60000 (64%)]	Loss: 0.021055
# Train Epoch: 58 [51200/60000 (85%)]	Loss: 0.042914
#
# Test set: Average loss: 0.0219, Accuracy: 9921/10000 (99%)
#
# Learning rate =  0.0001577792147882268
# Train Epoch: 59 [0/60000 (0%)]	Loss: 0.021235
# Train Epoch: 59 [12800/60000 (21%)]	Loss: 0.014779
# Train Epoch: 59 [25600/60000 (43%)]	Loss: 0.058915
# Train Epoch: 59 [38400/60000 (64%)]	Loss: 0.046056
# Train Epoch: 59 [51200/60000 (85%)]	Loss: 0.041271
#
# Test set: Average loss: 0.0220, Accuracy: 9917/10000 (99%)
#
# Learning rate =  0.00014989025404881545
# Train Epoch: 60 [0/60000 (0%)]	Loss: 0.035782
# Train Epoch: 60 [12800/60000 (21%)]	Loss: 0.082869
# Train Epoch: 60 [25600/60000 (43%)]	Loss: 0.081236
# Train Epoch: 60 [38400/60000 (64%)]	Loss: 0.016592
# Train Epoch: 60 [51200/60000 (85%)]	Loss: 0.004755
#
# Test set: Average loss: 0.0213, Accuracy: 9920/10000 (99%)
#
# Learning rate =  0.00014989025404881545
# Train Epoch: 61 [0/60000 (0%)]	Loss: 0.005352
# Train Epoch: 61 [12800/60000 (21%)]	Loss: 0.032566
# Train Epoch: 61 [25600/60000 (43%)]	Loss: 0.042774
# Train Epoch: 61 [38400/60000 (64%)]	Loss: 0.013771
# Train Epoch: 61 [51200/60000 (85%)]	Loss: 0.008236
#
# Test set: Average loss: 0.0224, Accuracy: 9923/10000 (99%)
#
# Learning rate =  0.00014239574134637466
# Train Epoch: 62 [0/60000 (0%)]	Loss: 0.012329
# Train Epoch: 62 [12800/60000 (21%)]	Loss: 0.032832
# Train Epoch: 62 [25600/60000 (43%)]	Loss: 0.010590
# Train Epoch: 62 [38400/60000 (64%)]	Loss: 0.021356
# Train Epoch: 62 [51200/60000 (85%)]	Loss: 0.036991
#
# Test set: Average loss: 0.0203, Accuracy: 9928/10000 (99%)
#
# Learning rate =  0.00014239574134637466
# Train Epoch: 63 [0/60000 (0%)]	Loss: 0.043860
# Train Epoch: 63 [12800/60000 (21%)]	Loss: 0.002572
# Train Epoch: 63 [25600/60000 (43%)]	Loss: 0.031200
# Train Epoch: 63 [38400/60000 (64%)]	Loss: 0.006043
# Train Epoch: 63 [51200/60000 (85%)]	Loss: 0.019786
#
# Test set: Average loss: 0.0218, Accuracy: 9925/10000 (99%)
#
# Learning rate =  0.00013527595427905592
# Train Epoch: 64 [0/60000 (0%)]	Loss: 0.009126
# Train Epoch: 64 [12800/60000 (21%)]	Loss: 0.012688
# Train Epoch: 64 [25600/60000 (43%)]	Loss: 0.015218
# Train Epoch: 64 [38400/60000 (64%)]	Loss: 0.030297
# Train Epoch: 64 [51200/60000 (85%)]	Loss: 0.012051
#
# Test set: Average loss: 0.0231, Accuracy: 9920/10000 (99%)
#
# Learning rate =  0.00012851215656510312
# Train Epoch: 65 [0/60000 (0%)]	Loss: 0.007737
# Train Epoch: 65 [12800/60000 (21%)]	Loss: 0.016630
# Train Epoch: 65 [25600/60000 (43%)]	Loss: 0.010401
# Train Epoch: 65 [38400/60000 (64%)]	Loss: 0.012709
# Train Epoch: 65 [51200/60000 (85%)]	Loss: 0.036733
#
# Test set: Average loss: 0.0208, Accuracy: 9930/10000 (99%)
#
# Learning rate =  0.00012851215656510312
# Train Epoch: 66 [0/60000 (0%)]	Loss: 0.016517
# Train Epoch: 66 [12800/60000 (21%)]	Loss: 0.003474
# Train Epoch: 66 [25600/60000 (43%)]	Loss: 0.006404
# Train Epoch: 66 [38400/60000 (64%)]	Loss: 0.002948
# Train Epoch: 66 [51200/60000 (85%)]	Loss: 0.026211
#
# Test set: Average loss: 0.0206, Accuracy: 9924/10000 (99%)
#
# Learning rate =  0.00012208654873684796
# Train Epoch: 67 [0/60000 (0%)]	Loss: 0.020745
# Train Epoch: 67 [12800/60000 (21%)]	Loss: 0.019866
# Train Epoch: 67 [25600/60000 (43%)]	Loss: 0.010107
# Train Epoch: 67 [38400/60000 (64%)]	Loss: 0.038417
# Train Epoch: 67 [51200/60000 (85%)]	Loss: 0.019332
#
# Test set: Average loss: 0.0206, Accuracy: 9933/10000 (99%)
#
# Learning rate =  0.00011598222130000556
# Train Epoch: 68 [0/60000 (0%)]	Loss: 0.072524
# Train Epoch: 68 [12800/60000 (21%)]	Loss: 0.024650
# Train Epoch: 68 [25600/60000 (43%)]	Loss: 0.002814
# Train Epoch: 68 [38400/60000 (64%)]	Loss: 0.015226
# Train Epoch: 68 [51200/60000 (85%)]	Loss: 0.056036
#
# Test set: Average loss: 0.0205, Accuracy: 9928/10000 (99%)
#
# Learning rate =  0.00011598222130000556
# Train Epoch: 69 [0/60000 (0%)]	Loss: 0.005025
# Train Epoch: 69 [12800/60000 (21%)]	Loss: 0.034018
# Train Epoch: 69 [25600/60000 (43%)]	Loss: 0.034411
# Train Epoch: 69 [38400/60000 (64%)]	Loss: 0.016854
# Train Epoch: 69 [51200/60000 (85%)]	Loss: 0.035199
#
# Test set: Average loss: 0.0205, Accuracy: 9926/10000 (99%)
#
# Learning rate =  0.00011018311023500529
# Train Epoch: 70 [0/60000 (0%)]	Loss: 0.017863
# Train Epoch: 70 [12800/60000 (21%)]	Loss: 0.026080
# Train Epoch: 70 [25600/60000 (43%)]	Loss: 0.023484
# Train Epoch: 70 [38400/60000 (64%)]	Loss: 0.027928
# Train Epoch: 70 [51200/60000 (85%)]	Loss: 0.004225
#
# Test set: Average loss: 0.0205, Accuracy: 9930/10000 (99%)
#
# Learning rate =  0.00011018311023500529
# Train Epoch: 71 [0/60000 (0%)]	Loss: 0.030133
# Train Epoch: 71 [12800/60000 (21%)]	Loss: 0.007068
# Train Epoch: 71 [25600/60000 (43%)]	Loss: 0.004832
# Train Epoch: 71 [38400/60000 (64%)]	Loss: 0.005210
# Train Epoch: 71 [51200/60000 (85%)]	Loss: 0.026603
#
# Test set: Average loss: 0.0210, Accuracy: 9929/10000 (99%)
#
# Learning rate =  0.00010467395472325501
# Train Epoch: 72 [0/60000 (0%)]	Loss: 0.004458
# Train Epoch: 72 [12800/60000 (21%)]	Loss: 0.013959
# Train Epoch: 72 [25600/60000 (43%)]	Loss: 0.016352
# Train Epoch: 72 [38400/60000 (64%)]	Loss: 0.029830
# Train Epoch: 72 [51200/60000 (85%)]	Loss: 0.018036
#
# Test set: Average loss: 0.0215, Accuracy: 9930/10000 (99%)
#
# Learning rate =  9.944025698709225e-05
# Train Epoch: 73 [0/60000 (0%)]	Loss: 0.089466
# Train Epoch: 73 [12800/60000 (21%)]	Loss: 0.003260
# Train Epoch: 73 [25600/60000 (43%)]	Loss: 0.024013
# Train Epoch: 73 [38400/60000 (64%)]	Loss: 0.050304
# Train Epoch: 73 [51200/60000 (85%)]	Loss: 0.031275
#
# Test set: Average loss: 0.0231, Accuracy: 9919/10000 (99%)
#
# Learning rate =  9.944025698709225e-05
# Train Epoch: 74 [0/60000 (0%)]	Loss: 0.017907
# Train Epoch: 74 [12800/60000 (21%)]	Loss: 0.004391
# Train Epoch: 74 [25600/60000 (43%)]	Loss: 0.010016
# Train Epoch: 74 [38400/60000 (64%)]	Loss: 0.002444
# Train Epoch: 74 [51200/60000 (85%)]	Loss: 0.002549
#
# Test set: Average loss: 0.0204, Accuracy: 9929/10000 (99%)
#
# Learning rate =  9.446824413773763e-05
# Train Epoch: 75 [0/60000 (0%)]	Loss: 0.008896
# Train Epoch: 75 [12800/60000 (21%)]	Loss: 0.007517
# Train Epoch: 75 [25600/60000 (43%)]	Loss: 0.015163
# Train Epoch: 75 [38400/60000 (64%)]	Loss: 0.009611
# Train Epoch: 75 [51200/60000 (85%)]	Loss: 0.005803
#
# Test set: Average loss: 0.0207, Accuracy: 9927/10000 (99%)
#
# Learning rate =  8.974483193085076e-05
# Train Epoch: 76 [0/60000 (0%)]	Loss: 0.043478
# Train Epoch: 76 [12800/60000 (21%)]	Loss: 0.005866
# Train Epoch: 76 [25600/60000 (43%)]	Loss: 0.048498
# Train Epoch: 76 [38400/60000 (64%)]	Loss: 0.030127
# Train Epoch: 76 [51200/60000 (85%)]	Loss: 0.003437
#
# Test set: Average loss: 0.0204, Accuracy: 9922/10000 (99%)
#
# Learning rate =  8.974483193085076e-05
# Train Epoch: 77 [0/60000 (0%)]	Loss: 0.007360
# Train Epoch: 77 [12800/60000 (21%)]	Loss: 0.027785
# Train Epoch: 77 [25600/60000 (43%)]	Loss: 0.007085
# Train Epoch: 77 [38400/60000 (64%)]	Loss: 0.035521
# Train Epoch: 77 [51200/60000 (85%)]	Loss: 0.013530
#
# Test set: Average loss: 0.0192, Accuracy: 9934/10000 (99%)
#
# Learning rate =  8.52575903343082e-05
# Train Epoch: 78 [0/60000 (0%)]	Loss: 0.022884
# Train Epoch: 78 [12800/60000 (21%)]	Loss: 0.017369
# Train Epoch: 78 [25600/60000 (43%)]	Loss: 0.074481
# Train Epoch: 78 [38400/60000 (64%)]	Loss: 0.014291
# Train Epoch: 78 [51200/60000 (85%)]	Loss: 0.020500
#
# Test set: Average loss: 0.0229, Accuracy: 9915/10000 (99%)
#
# Learning rate =  8.52575903343082e-05
# Train Epoch: 79 [0/60000 (0%)]	Loss: 0.010146
# Train Epoch: 79 [12800/60000 (21%)]	Loss: 0.015625
# Train Epoch: 79 [25600/60000 (43%)]	Loss: 0.005431
# Train Epoch: 79 [38400/60000 (64%)]	Loss: 0.010190
# Train Epoch: 79 [51200/60000 (85%)]	Loss: 0.018331
#
# Test set: Average loss: 0.0193, Accuracy: 9940/10000 (99%)
#
# Learning rate =  8.099471081759279e-05
# Train Epoch: 80 [0/60000 (0%)]	Loss: 0.017760
# Train Epoch: 80 [12800/60000 (21%)]	Loss: 0.003227
# Train Epoch: 80 [25600/60000 (43%)]	Loss: 0.017097
# Train Epoch: 80 [38400/60000 (64%)]	Loss: 0.006630
# Train Epoch: 80 [51200/60000 (85%)]	Loss: 0.008248
#
# Test set: Average loss: 0.0216, Accuracy: 9924/10000 (99%)
#
# Learning rate =  7.694497527671315e-05
# Train Epoch: 81 [0/60000 (0%)]	Loss: 0.013423
# Train Epoch: 81 [12800/60000 (21%)]	Loss: 0.024933
# Train Epoch: 81 [25600/60000 (43%)]	Loss: 0.033132
# Train Epoch: 81 [38400/60000 (64%)]	Loss: 0.011036
# Train Epoch: 81 [51200/60000 (85%)]	Loss: 0.010976
#
# Test set: Average loss: 0.0223, Accuracy: 9931/10000 (99%)
#
# Learning rate =  7.694497527671315e-05
# Train Epoch: 82 [0/60000 (0%)]	Loss: 0.029438
# Train Epoch: 82 [12800/60000 (21%)]	Loss: 0.005867
# Train Epoch: 82 [25600/60000 (43%)]	Loss: 0.007086
# Train Epoch: 82 [38400/60000 (64%)]	Loss: 0.025653
# Train Epoch: 82 [51200/60000 (85%)]	Loss: 0.032566
#
# Test set: Average loss: 0.0223, Accuracy: 9922/10000 (99%)
#
# Learning rate =  7.30977265128775e-05
# Train Epoch: 83 [0/60000 (0%)]	Loss: 0.057452
# Train Epoch: 83 [12800/60000 (21%)]	Loss: 0.017992
# Train Epoch: 83 [25600/60000 (43%)]	Loss: 0.013565
# Train Epoch: 83 [38400/60000 (64%)]	Loss: 0.030553
# Train Epoch: 83 [51200/60000 (85%)]	Loss: 0.047215
#
# Test set: Average loss: 0.0212, Accuracy: 9928/10000 (99%)
#
# Learning rate =  7.30977265128775e-05
# Train Epoch: 84 [0/60000 (0%)]	Loss: 0.004105
# Train Epoch: 84 [12800/60000 (21%)]	Loss: 0.007741
# Train Epoch: 84 [25600/60000 (43%)]	Loss: 0.005281
# Train Epoch: 84 [38400/60000 (64%)]	Loss: 0.018732
# Train Epoch: 84 [51200/60000 (85%)]	Loss: 0.023009
#
# Test set: Average loss: 0.0219, Accuracy: 9924/10000 (99%)
#
# Learning rate =  6.94428401872336e-05
# Train Epoch: 85 [0/60000 (0%)]	Loss: 0.004811
# Train Epoch: 85 [12800/60000 (21%)]	Loss: 0.035969
# Train Epoch: 85 [25600/60000 (43%)]	Loss: 0.029358
# Train Epoch: 85 [38400/60000 (64%)]	Loss: 0.042710
# Train Epoch: 85 [51200/60000 (85%)]	Loss: 0.015371
#
# Test set: Average loss: 0.0219, Accuracy: 9923/10000 (99%)
#
# Learning rate =  6.597069817787194e-05
# Train Epoch: 86 [0/60000 (0%)]	Loss: 0.021517
# Train Epoch: 86 [12800/60000 (21%)]	Loss: 0.019728
# Train Epoch: 86 [25600/60000 (43%)]	Loss: 0.009642
# Train Epoch: 86 [38400/60000 (64%)]	Loss: 0.015256
# Train Epoch: 86 [51200/60000 (85%)]	Loss: 0.011455
#
# Test set: Average loss: 0.0185, Accuracy: 9930/10000 (99%)
#
# Learning rate =  6.597069817787194e-05
# Train Epoch: 87 [0/60000 (0%)]	Loss: 0.023710
# Train Epoch: 87 [12800/60000 (21%)]	Loss: 0.015612
# Train Epoch: 87 [25600/60000 (43%)]	Loss: 0.007095
# Train Epoch: 87 [38400/60000 (64%)]	Loss: 0.009744
# Train Epoch: 87 [51200/60000 (85%)]	Loss: 0.007381
#
# Test set: Average loss: 0.0207, Accuracy: 9929/10000 (99%)
#
# Learning rate =  6.267216326897833e-05
# Train Epoch: 88 [0/60000 (0%)]	Loss: 0.024556
# Train Epoch: 88 [12800/60000 (21%)]	Loss: 0.016159
# Train Epoch: 88 [25600/60000 (43%)]	Loss: 0.002192
# Train Epoch: 88 [38400/60000 (64%)]	Loss: 0.012467
# Train Epoch: 88 [51200/60000 (85%)]	Loss: 0.004426
#
# Test set: Average loss: 0.0222, Accuracy: 9926/10000 (99%)
#
# Learning rate =  5.953855510552941e-05
# Train Epoch: 89 [0/60000 (0%)]	Loss: 0.015021
# Train Epoch: 89 [12800/60000 (21%)]	Loss: 0.009078
# Train Epoch: 89 [25600/60000 (43%)]	Loss: 0.008061
# Train Epoch: 89 [38400/60000 (64%)]	Loss: 0.005289
# Train Epoch: 89 [51200/60000 (85%)]	Loss: 0.004916
#
# Test set: Average loss: 0.0209, Accuracy: 9934/10000 (99%)
#
# Learning rate =  5.953855510552941e-05
# Train Epoch: 90 [0/60000 (0%)]	Loss: 0.037801
# Train Epoch: 90 [12800/60000 (21%)]	Loss: 0.014101
# Train Epoch: 90 [25600/60000 (43%)]	Loss: 0.008349
# Train Epoch: 90 [38400/60000 (64%)]	Loss: 0.007870
# Train Epoch: 90 [51200/60000 (85%)]	Loss: 0.022675
#
# Test set: Average loss: 0.0210, Accuracy: 9927/10000 (99%)
#
# Learning rate =  5.656162735025293e-05
# Train Epoch: 91 [0/60000 (0%)]	Loss: 0.015111
# Train Epoch: 91 [12800/60000 (21%)]	Loss: 0.049946
# Train Epoch: 91 [25600/60000 (43%)]	Loss: 0.005813
# Train Epoch: 91 [38400/60000 (64%)]	Loss: 0.038024
# Train Epoch: 91 [51200/60000 (85%)]	Loss: 0.003891
#
# Test set: Average loss: 0.0203, Accuracy: 9933/10000 (99%)
#
# Learning rate =  5.656162735025293e-05
# Train Epoch: 92 [0/60000 (0%)]	Loss: 0.006998
# Train Epoch: 92 [12800/60000 (21%)]	Loss: 0.003301
# Train Epoch: 92 [25600/60000 (43%)]	Loss: 0.008795
# Train Epoch: 92 [38400/60000 (64%)]	Loss: 0.047988
# Train Epoch: 92 [51200/60000 (85%)]	Loss: 0.008499
#
# Test set: Average loss: 0.0221, Accuracy: 9919/10000 (99%)
#
# Learning rate =  5.373354598274029e-05
# Train Epoch: 93 [0/60000 (0%)]	Loss: 0.002044
# Train Epoch: 93 [12800/60000 (21%)]	Loss: 0.014031
# Train Epoch: 93 [25600/60000 (43%)]	Loss: 0.006344
# Train Epoch: 93 [38400/60000 (64%)]	Loss: 0.015267
# Train Epoch: 93 [51200/60000 (85%)]	Loss: 0.004737
#
# Test set: Average loss: 0.0212, Accuracy: 9927/10000 (99%)
#
# Learning rate =  5.1046868683603266e-05
# Train Epoch: 94 [0/60000 (0%)]	Loss: 0.011531
# Train Epoch: 94 [12800/60000 (21%)]	Loss: 0.012301
# Train Epoch: 94 [25600/60000 (43%)]	Loss: 0.104281
# Train Epoch: 94 [38400/60000 (64%)]	Loss: 0.009056
# Train Epoch: 94 [51200/60000 (85%)]	Loss: 0.002577
#
# Test set: Average loss: 0.0209, Accuracy: 9926/10000 (99%)
#
# Learning rate =  5.1046868683603266e-05
# Train Epoch: 95 [0/60000 (0%)]	Loss: 0.001421
# Train Epoch: 95 [12800/60000 (21%)]	Loss: 0.044743
# Train Epoch: 95 [25600/60000 (43%)]	Loss: 0.004251
# Train Epoch: 95 [38400/60000 (64%)]	Loss: 0.036163
# Train Epoch: 95 [51200/60000 (85%)]	Loss: 0.057450
#
# Test set: Average loss: 0.0206, Accuracy: 9936/10000 (99%)
#
# Learning rate =  4.8494525249423105e-05
# Train Epoch: 96 [0/60000 (0%)]	Loss: 0.017255
# Train Epoch: 96 [12800/60000 (21%)]	Loss: 0.014696
# Train Epoch: 96 [25600/60000 (43%)]	Loss: 0.016783
# Train Epoch: 96 [38400/60000 (64%)]	Loss: 0.013120
# Train Epoch: 96 [51200/60000 (85%)]	Loss: 0.009940
#
# Test set: Average loss: 0.0212, Accuracy: 9922/10000 (99%)
#
# Learning rate =  4.6069798986951947e-05
# Train Epoch: 97 [0/60000 (0%)]	Loss: 0.027449
# Train Epoch: 97 [12800/60000 (21%)]	Loss: 0.018492
# Train Epoch: 97 [25600/60000 (43%)]	Loss: 0.015083
# Train Epoch: 97 [38400/60000 (64%)]	Loss: 0.011903
# Train Epoch: 97 [51200/60000 (85%)]	Loss: 0.006699
#
# Test set: Average loss: 0.0214, Accuracy: 9925/10000 (99%)
#
# Learning rate =  4.6069798986951947e-05
# Train Epoch: 98 [0/60000 (0%)]	Loss: 0.004594
# Train Epoch: 98 [12800/60000 (21%)]	Loss: 0.004398
# Train Epoch: 98 [25600/60000 (43%)]	Loss: 0.014790
# Train Epoch: 98 [38400/60000 (64%)]	Loss: 0.048334
# Train Epoch: 98 [51200/60000 (85%)]	Loss: 0.007990
#
# Test set: Average loss: 0.0210, Accuracy: 9919/10000 (99%)
#
# Learning rate =  4.3766309037604346e-05
# Train Epoch: 99 [0/60000 (0%)]	Loss: 0.014348
# Train Epoch: 99 [12800/60000 (21%)]	Loss: 0.052981
# Train Epoch: 99 [25600/60000 (43%)]	Loss: 0.003479
# Train Epoch: 99 [38400/60000 (64%)]	Loss: 0.019244
# Train Epoch: 99 [51200/60000 (85%)]	Loss: 0.040190
#
# Test set: Average loss: 0.0221, Accuracy: 9930/10000 (99%)
#
# Total time taken: 5726 seconds

# %%
import matplotlib.pyplot as plt
plt.plot(learning_rate, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Losses');

# %%
import matplotlib.pyplot as plt
plt.plot(losses_1, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Losses');

# %%
import matplotlib.pyplot as plt
plt.plot(losses_2, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Losses');

# %%
import matplotlib.pyplot as plt
plt.plot(avg_loss, '-')
plt.xlabel('epoch')
plt.ylabel('Avg Loss')
plt.title('Average Loss');

# %%
import matplotlib.pyplot as plt
plt.plot(accuracy, '-')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Acc');

# %%
torch.save(model, '2_model_MNIST_3579_Adagrad_0.95_100e.pth')
